# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from config import google_api_key
import json
import requests
import sqlite3
from sqlalchemy import create_engine

# %% [markdown]
# ## 1. Extract city and state based on zip code

# %% [markdown]
# ### 1.1. Loading raw data

# %%
# Load dataset
df = pd.read_csv("../data/lender_data.csv", skiprows=1, dtype={'Zip': object})

# Drop rows that are all NaN's
df = df.dropna(how='all')
df.head()
# Out:
#    Deal ID  Lender ID    Zip  City  State Multifamily Subtype Built   Units  \
# 0  14454.0       19.0  92626   NaN    NaN              Garden  1990    24.0
# 1  20421.0       19.0  91406   NaN    NaN              Garden  1962    15.0
# 2  24298.0       50.0  70122   NaN    NaN              Garden  2009   164.0
# 3   2853.0       19.0  90046   NaN    NaN              Garden  1957    11.0
# 4   3023.0       51.0  11215   NaN    NaN              Garden  2002    13.0
#
#   Original Loan  Note Rate  Loan Term (Original) Appraised Value  \
# 0      1,720,000      5.8%                 180.0       3,500,000
# 1        500,000      5.3%                 180.0       1,525,000
# 2        250,000      6.9%                 120.0       4,187,586
# 3        805,000      5.2%                 180.0       2,450,000
# 4      1,600,000      6.5%                 120.0       3,112,000
#
#   Maturity Date      UPB Amort DSvc  Orig Amort  IO Period  Unnamed: 17  \
# 0        2/1/19   28,379     14,292       180.0        0.0          NaN
# 1       12/1/19   46,916      4,022       180.0        0.0          NaN
# 2        1/1/21   67,161      2,892       120.0        0.0          NaN
# 3        8/1/20  123,314      6,450       180.0        0.0          NaN
# 4        7/1/19  124,669     18,200       120.0        0.0          NaN
#
#    Unnamed: 18
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# Drop meaningless columns "Unnamed: 17", "Unnamed: 18"
df = df.drop(columns=[col for col in df.columns.tolist() if 'Unnamed' in col])

# Overview of dataset
print(f"There are {df.shape[0]} rows in the dataset.")

# Number of missing values in each column
print("Number of missing values in each column:")
df.isnull().sum()
# Out:
# There are 29130 rows in the dataset.
# Number of missing values in each column:
# Deal ID                     0
# Lender ID                   0
# Zip                         0
# City                    29130
# State                   29130
# Multifamily Subtype         0
# Built                       0
#  Units                      0
# Original Loan               0
# Note Rate                   0
# Loan Term (Original)        0
# Appraised Value             0
# Maturity Date               0
# UPB                         0
# Amort DSvc                  0
# Orig Amort                  0
# IO Period                   0
# dtype: int64

# %%
# Number of unique values
print("Number of unique values in each column:")
df.nunique()
# Out:
# Number of unique values in each column:
# Deal ID                 29128
# Lender ID                  58
# Zip                      6974
# City                        0
# State                       0
# Multifamily Subtype        20
# Built                     165
#  Units                    886
# Original Loan           12396
# Note Rate                  77
# Loan Term (Original)       90
# Appraised Value          7022
# Maturity Date             387
# UPB                     25261
# Amort DSvc              25552
# Orig Amort                 45
# IO Period                  35
# dtype: int64

# %% [markdown]
# ### 1.2. Fill in city and state blanks
#
# Use [Google Geocoding API](https://developers.google.com/maps/documentation/geocoding/intro) to get the City and State for each deal from the Zip Code provided.

# %%
# Construct API query
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
params = {"key": google_api_key}

# %%
# Create a list of unique zip code to look up
zipcode_unique = df['Zip'].unique().tolist()

# %%
# results_list = []
# for index, zipcode in enumerate(zipcode_unique):
    
#     target_zipcode = zipcode
#     params['components'] = f"country:US|postal_code:{target_zipcode}"
#     print(f"Retrieving Results for Index {index}: {target_zipcode}.")

#     response = requests.get(base_url, params=params).json()
#     results = response.get('results')
#     results_list.append(results)
# Out:
# Retrieving Results for Index 0: 92626.
# Retrieving Results for Index 1: 91406.
# Retrieving Results for Index 2: 70122.
# Retrieving Results for Index 3: 90046.
# Retrieving Results for Index 4: 11215.
# Retrieving Results for Index 5: 66062.
# Retrieving Results for Index 6: 90245.
# Retrieving Results for Index 7: 13601.
# Retrieving Results for Index 8: 95117.
# Retrieving Results for Index 9: 31806.
# Retrieving Results for Index 10: 90068.
# Retrieving Results for Index 11: 90262.
# Retrieving Results for Index 12: 31096.
# Retrieving Results for Index 13: 31002.
# Retrieving Results for Index 14: 91204.
# Retrieving Results for Index 15: 30428.
# Retrieving Results for Index 16: 30411.
# Retrieving Results for Index 17: 31824.
# Retrieving Results for Index 18: 02062.
# Retrieving Results for Index 19: 31091.
# Retrieving Results for Index 20: 30810.
# Retrieving Results for Index 21: 83631.
# Retrieving Results for Index 22: 98208.
# Retrieving Results for Index 23: 83318.
# Retrieving Results for Index 24: 31650.
# Retrieving Results for Index 25: 92504.
# Retrieving Results for Index 26: 92102.
# Retrieving Results for Index 27: 06511.
# Retrieving Results for Index 28: 91602.
# Retrieving Results for Index 29: 72143.
# Retrieving Results for Index 30: 94110.
# Retrieving Results for Index 31: 83605.
# Retrieving Results for Index 32: 55112.
# Retrieving Results for Index 33: 90631.
# Retrieving Results for Index 34: 90038.
# Retrieving Results for Index 35: 30434.
# Retrieving Results for Index 36: 20002.
# Retrieving Results for Index 37: 92706.
# Retrieving Results for Index 38: 53227.
# Retrieving Results for Index 39: 11102.
# Retrieving Results for Index 40: 90744.
# Retrieving Results for Index 41: 30453.
# Retrieving Results for Index 42: 85349.
# Retrieving Results for Index 43: 30540.
# Retrieving Results for Index 44: 91201.
# Retrieving Results for Index 45: 90005.
# Retrieving Results for Index 46: 91303.
# Retrieving Results for Index 47: 91411.
# Retrieving Results for Index 48: 90291.
# Retrieving Results for Index 49: 30295.
# Retrieving Results for Index 50: 91205.
# Retrieving Results for Index 51: 31001.
# Retrieving Results for Index 52: 90403.
# Retrieving Results for Index 53: 93060.
# Retrieving Results for Index 54: 23970.
# Retrieving Results for Index 55: 02141.
# Retrieving Results for Index 56: 30477.
# Retrieving Results for Index 57: 90069.
# Retrieving Results for Index 58: 90019.
# Retrieving Results for Index 59: 92116.
# Retrieving Results for Index 60: 90731.
# Retrieving Results for Index 61: 30113.
# Retrieving Results for Index 62: 74937.
# Retrieving Results for Index 63: 83661.
# Retrieving Results for Index 64: 90066.
# Retrieving Results for Index 65: 20009.
# Retrieving Results for Index 66: 60625.
# Retrieving Results for Index 67: 10128.
# Retrieving Results for Index 68: 93726.
# Retrieving Results for Index 69: 91604.
# Retrieving Results for Index 70: 90302.
# Retrieving Results for Index 71: 83705.
# Retrieving Results for Index 72: 83341.
# Retrieving Results for Index 73: 90008.
# Retrieving Results for Index 74: 92020.
# Retrieving Results for Index 75: 90034.
# Retrieving Results for Index 76: 30307.
# Retrieving Results for Index 77: 02118.
# Retrieving Results for Index 78: 33130.
# Retrieving Results for Index 79: 92806.
# Retrieving Results for Index 80: 28205.
# Retrieving Results for Index 81: 71107.
# Retrieving Results for Index 82: 30630.
# Retrieving Results for Index 83: 92024.
# Retrieving Results for Index 84: 91762.
# Retrieving Results for Index 85: 97223.
# Retrieving Results for Index 86: 94941.
# Retrieving Results for Index 87: 60653.
# Retrieving Results for Index 88: 37665.
# Retrieving Results for Index 89: 29690.
# Retrieving Results for Index 90: 55426.
# Retrieving Results for Index 91: 47441.
# Retrieving Results for Index 92: 75219.
# Retrieving Results for Index 93: 43506.
# Retrieving Results for Index 94: 98335.
# Retrieving Results for Index 95: 43812.
# Retrieving Results for Index 96: 90064.
# Retrieving Results for Index 97: 61604.
# Retrieving Results for Index 98: 44120.
# Retrieving Results for Index 99: 85003.
# Retrieving Results for Index 100: 95628.
# Retrieving Results for Index 101: 07017.
# Retrieving Results for Index 102: 11225.
# Retrieving Results for Index 103: 01904.
# Retrieving Results for Index 104: 11222.
# Retrieving Results for Index 105: 70115.
# Retrieving Results for Index 106: 90042.
# Retrieving Results for Index 107: 91977.
# Retrieving Results for Index 108: 94544.
# Retrieving Results for Index 109: 91343.
# Retrieving Results for Index 110: 91932.
# Retrieving Results for Index 111: 92701.
# Retrieving Results for Index 112: 92083.
# Retrieving Results for Index 113: 72401.
# Retrieving Results for Index 114: 91107.
# Retrieving Results for Index 115: 90405.
# Retrieving Results for Index 116: 31750.
# Retrieving Results for Index 117: 12550.
# Retrieving Results for Index 118: 92104.
# Retrieving Results for Index 119: 23608.
# Retrieving Results for Index 120: 63143.
# Retrieving Results for Index 121: 98310.
# Retrieving Results for Index 122: 92672.
# Retrieving Results for Index 123: 33909.
# Retrieving Results for Index 124: 95122.
# Retrieving Results for Index 125: 07928.
# Retrieving Results for Index 126: 99709.
# Retrieving Results for Index 127: 10591.
# Retrieving Results for Index 128: 92028.
# Retrieving Results for Index 129: 92506.
# Retrieving Results for Index 130: 90293.
# Retrieving Results for Index 131: 92262.
# Retrieving Results for Index 132: 71245.
# Retrieving Results for Index 133: 71302.
# Retrieving Results for Index 134: 90802.
# Retrieving Results for Index 135: 60804.
# Retrieving Results for Index 136: 20020.
# Retrieving Results for Index 137: 98465.
# Retrieving Results for Index 138: 91401.
# Retrieving Results for Index 139: 29488.
# Retrieving Results for Index 140: 91405.
# Retrieving Results for Index 141: 60060.
# Retrieving Results for Index 142: 60612.
# Retrieving Results for Index 143: 91306.
# Retrieving Results for Index 144: 01843.
# Retrieving Results for Index 145: 97210.
# Retrieving Results for Index 146: 90043.
# Retrieving Results for Index 147: 97060.
# Retrieving Results for Index 148: 60126.
# Retrieving Results for Index 149: 98661.
# Retrieving Results for Index 150: 29691.
# Retrieving Results for Index 151: 10457.
# Retrieving Results for Index 152: 90029.
# Retrieving Results for Index 153: 92627.
# Retrieving Results for Index 154: 91501.
# Retrieving Results for Index 155: 70130.
# Retrieving Results for Index 156: 72830.
# Retrieving Results for Index 157: 90803.
# Retrieving Results for Index 158: 90007.
# Retrieving Results for Index 159: 94122.
# Retrieving Results for Index 160: 35205.
# Retrieving Results for Index 161: 40160.
# Retrieving Results for Index 162: 90241.
# Retrieving Results for Index 163: 97221.
# Retrieving Results for Index 164: 95616.
# Retrieving Results for Index 165: 97138.
# Retrieving Results for Index 166: 77568.
# Retrieving Results for Index 167: 60613.
# Retrieving Results for Index 168: 91016.
# Retrieving Results for Index 169: 91605.
# Retrieving Results for Index 170: 98366.
# Retrieving Results for Index 171: 23509.
# Retrieving Results for Index 172: 28704.
# Retrieving Results for Index 173: 24017.
# Retrieving Results for Index 174: 91801.
# Retrieving Results for Index 175: 90057.
# Retrieving Results for Index 176: 90248.
# Retrieving Results for Index 177: 37040.
# Retrieving Results for Index 178: 20008.
# Retrieving Results for Index 179: 43085.
# Retrieving Results for Index 180: 94107.
# Retrieving Results for Index 181: 98020.
# Retrieving Results for Index 182: 60640.
# Retrieving Results for Index 183: 29445.
# Retrieving Results for Index 184: 28206.
# Retrieving Results for Index 185: 48084.
# Retrieving Results for Index 186: 91402.
# Retrieving Results for Index 187: 77055.
# Retrieving Results for Index 188: 77092.
# Retrieving Results for Index 189: 55119.
# Retrieving Results for Index 190: 93445.
# Retrieving Results for Index 191: 40272.
# Retrieving Results for Index 192: 55408.
# Retrieving Results for Index 193: 01826.
# Retrieving Results for Index 194: 61008.
# Retrieving Results for Index 195: 60626.
# Retrieving Results for Index 196: 73401.
# Retrieving Results for Index 197: 03878.
# Retrieving Results for Index 198: 71854.
# Retrieving Results for Index 199: 90723.
# Retrieving Results for Index 200: 90401.
# Retrieving Results for Index 201: 60645.
# Retrieving Results for Index 202: 90020.
# Retrieving Results for Index 203: 97383.
# Retrieving Results for Index 204: 90301.
# Retrieving Results for Index 205: 45219.
# Retrieving Results for Index 206: 55428.
# Retrieving Results for Index 207: 72160.
# Retrieving Results for Index 208: 28083.
# Retrieving Results for Index 209: 90027.
# Retrieving Results for Index 210: 90621.
# Retrieving Results for Index 211: 78208.
# Retrieving Results for Index 212: 93033.
# Retrieving Results for Index 213: 92109.
# Retrieving Results for Index 214: 70805.
# Retrieving Results for Index 215: 91706.
# Retrieving Results for Index 216: 98662.
# Retrieving Results for Index 217: 90815.
# Retrieving Results for Index 218: 71115.
# Retrieving Results for Index 219: 61820.
# Retrieving Results for Index 220: 07050.
# Retrieving Results for Index 221: 92025.
# Retrieving Results for Index 222: 90804.
# Retrieving Results for Index 223: 60415.
# Retrieving Results for Index 224: 60506.
# Retrieving Results for Index 225: 92105.
# Retrieving Results for Index 226: 97502.
# Retrieving Results for Index 227: 25813.
# Retrieving Results for Index 228: 84010.
# Retrieving Results for Index 229: 55117.
# Retrieving Results for Index 230: 06105.
# Retrieving Results for Index 231: 90660.
# Retrieving Results for Index 232: 90045.
# Retrieving Results for Index 233: 90006.
# Retrieving Results for Index 234: 10022.
# Retrieving Results for Index 235: 91910.
# Retrieving Results for Index 236: 90255.
# Retrieving Results for Index 237: 80903.
# Retrieving Results for Index 238: 94070.
# Retrieving Results for Index 239: 91001.
# Retrieving Results for Index 240: 84109.
# Retrieving Results for Index 241: 98136.
# Retrieving Results for Index 242: 90249.
# Retrieving Results for Index 243: 35124.
# Retrieving Results for Index 244: 88310.
# Retrieving Results for Index 245: 60202.
# Retrieving Results for Index 246: 83338.
# Retrieving Results for Index 247: 84105.
# Retrieving Results for Index 248: 91364.
# Retrieving Results for Index 249: 10456.
# Retrieving Results for Index 250: 91770.
# Retrieving Results for Index 251: 76648.
# Retrieving Results for Index 252: 02169.
# Retrieving Results for Index 253: 60641.
# Retrieving Results for Index 254: 46573.
# Retrieving Results for Index 255: 90242.
# Retrieving Results for Index 256: 92118.
# Retrieving Results for Index 257: 97526.
# Retrieving Results for Index 258: 72301.
# Retrieving Results for Index 259: 70118.
# Retrieving Results for Index 260: 94117.
# Retrieving Results for Index 261: 60642.
# Retrieving Results for Index 262: 53555.
# Retrieving Results for Index 263: 98103.
# Retrieving Results for Index 264: 93705.
# Retrieving Results for Index 265: 95688.
# Retrieving Results for Index 266: 93436.
# Retrieving Results for Index 267: 94103.
# Retrieving Results for Index 268: 90604.
# Retrieving Results for Index 269: 24541.
# Retrieving Results for Index 270: 49017.
# Retrieving Results for Index 271: 48009.
# Retrieving Results for Index 272: 93001.
# Retrieving Results for Index 273: 90035.
# Retrieving Results for Index 274: 10512.
# Retrieving Results for Index 275: 90212.
# Retrieving Results for Index 276: 73114.
# Retrieving Results for Index 277: 11435.
# Retrieving Results for Index 278: 58203.
# Retrieving Results for Index 279: 84103.
# Retrieving Results for Index 280: 92101.
# Retrieving Results for Index 281: 11237.
# Retrieving Results for Index 282: 76065.
# Retrieving Results for Index 283: 44107.
# Retrieving Results for Index 284: 44102.
# Retrieving Results for Index 285: 10705.
# Retrieving Results for Index 286: 37405.
# Retrieving Results for Index 287: 07103.
# Retrieving Results for Index 288: 91755.
# Retrieving Results for Index 289: 53208.
# Retrieving Results for Index 290: 91606.
# Retrieving Results for Index 291: 59601.
# Retrieving Results for Index 292: 90280.
# Retrieving Results for Index 293: 07087.
# Retrieving Results for Index 294: 44691.
# Retrieving Results for Index 295: 33702.
# Retrieving Results for Index 296: 84107.
# Retrieving Results for Index 297: 91030.
# Retrieving Results for Index 298: 21202.
# Retrieving Results for Index 299: 60015.
# Retrieving Results for Index 300: 97203.
# Retrieving Results for Index 301: 11221.
# Retrieving Results for Index 302: 91601.
# Retrieving Results for Index 303: 95815.
# Retrieving Results for Index 304: 46072.
# Retrieving Results for Index 305: 78704.
# Retrieving Results for Index 306: 28209.
# Retrieving Results for Index 307: 92107.
# Retrieving Results for Index 308: 06112.
# Retrieving Results for Index 309: 52302.
# Retrieving Results for Index 310: 03820.
# Retrieving Results for Index 311: 19026.
# Retrieving Results for Index 312: 93280.
# Retrieving Results for Index 313: 75904.
# Retrieving Results for Index 314: 33162.
# Retrieving Results for Index 315: 91731.
# Retrieving Results for Index 316: 91203.
# Retrieving Results for Index 317: 23834.
# Retrieving Results for Index 318: 38375.
# Retrieving Results for Index 319: 95341.
# Retrieving Results for Index 320: 92651.
# Retrieving Results for Index 321: 07018.
# Retrieving Results for Index 322: 93101.
# Retrieving Results for Index 323: 66101.
# Retrieving Results for Index 324: 97214.
# Retrieving Results for Index 325: 80304.
# Retrieving Results for Index 326: 99163.
# Retrieving Results for Index 327: 94118.
# Retrieving Results for Index 328: 07105.
# Retrieving Results for Index 329: 20678.
# Retrieving Results for Index 330: 72543.
# Retrieving Results for Index 331: 22205.
# Retrieving Results for Index 332: 03301.
# Retrieving Results for Index 333: 53051.
# Retrieving Results for Index 334: 97058.
# Retrieving Results for Index 335: 90706.
# Retrieving Results for Index 336: 53403.
# Retrieving Results for Index 337: 92683.
# Retrieving Results for Index 338: 90247.
# Retrieving Results for Index 339: 06604.
# Retrieving Results for Index 340: 91732.
# Retrieving Results for Index 341: 89431.
# Retrieving Results for Index 342: 39440.
# Retrieving Results for Index 343: 99204.
# Retrieving Results for Index 344: 72103.
# Retrieving Results for Index 345: 84115.
# Retrieving Results for Index 346: 90004.
# Retrieving Results for Index 347: 37208.
# Retrieving Results for Index 348: 60619.
# Retrieving Results for Index 349: 89506.
# Retrieving Results for Index 350: 60614.
# Retrieving Results for Index 351: 36609.
# Retrieving Results for Index 352: 75206.
# Retrieving Results for Index 353: 33755.
# Retrieving Results for Index 354: 49508.
# Retrieving Results for Index 355: 91941.
# Retrieving Results for Index 356: 81611.
# Retrieving Results for Index 357: 90026.
# Retrieving Results for Index 358: 29301.
# Retrieving Results for Index 359: 60657.
# Retrieving Results for Index 360: 89503.
# Retrieving Results for Index 361: 38701.
# Retrieving Results for Index 362: 39180.
# Retrieving Results for Index 363: 90807.
# Retrieving Results for Index 364: 91304.
# Retrieving Results for Index 365: 02864.
# Retrieving Results for Index 366: 72113.
# Retrieving Results for Index 367: 83501.
# Retrieving Results for Index 368: 11208.
# Retrieving Results for Index 369: 07514.
# Retrieving Results for Index 370: 60540.
# Retrieving Results for Index 371: 26003.
# Retrieving Results for Index 372: 71108.
# Retrieving Results for Index 373: 11783.
# Retrieving Results for Index 374: 50263.
# Retrieving Results for Index 375: 89436.
# Retrieving Results for Index 376: 71730.
# Retrieving Results for Index 377: 11217.
# Retrieving Results for Index 378: 91206.
# Retrieving Results for Index 379: 94115.
# Retrieving Results for Index 380: 77019.
# Retrieving Results for Index 381: 52205.
# Retrieving Results for Index 382: 07106.
# Retrieving Results for Index 383: 78221.
# Retrieving Results for Index 384: 70458.
# Retrieving Results for Index 385: 90602.
# Retrieving Results for Index 386: 97501.
# Retrieving Results for Index 387: 11206.
# Retrieving Results for Index 388: 90041.
# Retrieving Results for Index 389: 90304.
# Retrieving Results for Index 390: 60622.
# Retrieving Results for Index 391: 77017.
# Retrieving Results for Index 392: 76426.
# Retrieving Results for Index 393: 92273.
# Retrieving Results for Index 394: 60644.
# Retrieving Results for Index 395: 37055.
# Retrieving Results for Index 396: 60660.
# Retrieving Results for Index 397: 75060.
# Retrieving Results for Index 398: 83712.
# Retrieving Results for Index 399: 85251.
# Retrieving Results for Index 400: 10977.
# Retrieving Results for Index 401: 98270.
# Retrieving Results for Index 402: 27101.
# Retrieving Results for Index 403: 92110.
# Retrieving Results for Index 404: 90250.
# Retrieving Results for Index 405: 63110.
# Retrieving Results for Index 406: 36567.
# Retrieving Results for Index 407: 01040.
# Retrieving Results for Index 408: 07042.
# Retrieving Results for Index 409: 94610.
# Retrieving Results for Index 410: 39846.
# Retrieving Results for Index 411: 02904.
# Retrieving Results for Index 412: 44112.
# Retrieving Results for Index 413: 92345.
# Retrieving Results for Index 414: 97322.
# Retrieving Results for Index 415: 83854.
# Retrieving Results for Index 416: 55435.
# Retrieving Results for Index 417: 74074.
# Retrieving Results for Index 418: 83706.
# Retrieving Results for Index 419: 60659.
# Retrieving Results for Index 420: 11238.
# Retrieving Results for Index 421: 78578.
# Retrieving Results for Index 422: 27405.
# Retrieving Results for Index 423: 11216.
# Retrieving Results for Index 424: 16001.
# Retrieving Results for Index 425: 08609.
# Retrieving Results for Index 426: 44109.
# Retrieving Results for Index 427: 90044.
# Retrieving Results for Index 428: 92113.
# Retrieving Results for Index 429: 40208.
# Retrieving Results for Index 430: 90232.
# Retrieving Results for Index 431: 17522.
# Retrieving Results for Index 432: 97603.
# Retrieving Results for Index 433: 39117.
# Retrieving Results for Index 434: 32405.
# Retrieving Results for Index 435: 01108.
# Retrieving Results for Index 436: 55106.
# Retrieving Results for Index 437: 90240.
# Retrieving Results for Index 438: 36695.
# Retrieving Results for Index 439: 98665.
# Retrieving Results for Index 440: 90028.
# Retrieving Results for Index 441: 56304.
# Retrieving Results for Index 442: 31419.
# Retrieving Results for Index 443: 92801.
# Retrieving Results for Index 444: 90813.
# Retrieving Results for Index 445: 10003.
# Retrieving Results for Index 446: 92804.
# Retrieving Results for Index 447: 40203.
# Retrieving Results for Index 448: 91776.
# Retrieving Results for Index 449: 31709.
# Retrieving Results for Index 450: 90501.
# Retrieving Results for Index 451: 93405.
# Retrieving Results for Index 452: 66720.
# Retrieving Results for Index 453: 43055.
# Retrieving Results for Index 454: 91607.
# Retrieving Results for Index 455: 48858.
# Retrieving Results for Index 456: 27105.
# Retrieving Results for Index 457: 02114.
# Retrieving Results for Index 458: 10009.
# Retrieving Results for Index 459: 60302.
# Retrieving Results for Index 460: 48066.
# Retrieving Results for Index 461: 36606.
# Retrieving Results for Index 462: 32804.
# Retrieving Results for Index 463: 80302.
# Retrieving Results for Index 464: 11212.
# Retrieving Results for Index 465: 79928.
# Retrieving Results for Index 466: 31827.
# Retrieving Results for Index 467: 95991.
# Retrieving Results for Index 468: 90504.
# Retrieving Results for Index 469: 33614.
# Retrieving Results for Index 470: 72114.
# Retrieving Results for Index 471: 06518.
# Retrieving Results for Index 472: 97030.
# Retrieving Results for Index 473: 85364.
# Retrieving Results for Index 474: 77511.
# Retrieving Results for Index 475: 60647.
# Retrieving Results for Index 476: 33404.
# Retrieving Results for Index 477: 97303.
# Retrieving Results for Index 478: 11377.
# Retrieving Results for Index 479: 72032.
# Retrieving Results for Index 480: 19115.
# Retrieving Results for Index 481: 71457.
# Retrieving Results for Index 482: 90048.
# Retrieving Results for Index 483: 30308.
# Retrieving Results for Index 484: 98006.
# Retrieving Results for Index 485: 32603.
# Retrieving Results for Index 486: 29620.
# Retrieving Results for Index 487: 75961.
# Retrieving Results for Index 488: 03801.
# Retrieving Results for Index 489: 14209.
# Retrieving Results for Index 490: 84054.
# Retrieving Results for Index 491: 94541.
# Retrieving Results for Index 492: 23455.
# Retrieving Results for Index 493: 63033.
# Retrieving Results for Index 494: 33145.
# Retrieving Results for Index 495: 32801.
# Retrieving Results for Index 496: 91335.
# Retrieving Results for Index 497: 44857.
# Retrieving Results for Index 498: 83642.
# Retrieving Results for Index 499: 34112.
# Retrieving Results for Index 500: 11103.
# Retrieving Results for Index 501: 85365.
# Retrieving Results for Index 502: 91352.
# Retrieving Results for Index 503: 02130.
# Retrieving Results for Index 504: 49204.
# Retrieving Results for Index 505: 70401.
# Retrieving Results for Index 506: 02723.
# Retrieving Results for Index 507: 06278.
# Retrieving Results for Index 508: 77327.
# Retrieving Results for Index 509: 10458.
# Retrieving Results for Index 510: 90036.
# Retrieving Results for Index 511: 30306.
# Retrieving Results for Index 512: 21229.
# Retrieving Results for Index 513: 29577.
# Retrieving Results for Index 514: 19104.
# Retrieving Results for Index 515: 98107.
# Retrieving Results for Index 516: 98112.
# Retrieving Results for Index 517: 93534.
# Retrieving Results for Index 518: 29073.
# Retrieving Results for Index 519: 30072.
# Retrieving Results for Index 520: 60638.
# Retrieving Results for Index 521: 21740.
# Retrieving Results for Index 522: 44122.
# Retrieving Results for Index 523: 20710.
# Retrieving Results for Index 524: 90805.
# Retrieving Results for Index 525: 91356.
# Retrieving Results for Index 526: 29642.
# Retrieving Results for Index 527: 84104.
# Retrieving Results for Index 528: 60649.
# Retrieving Results for Index 529: 98031.
# Retrieving Results for Index 530: 72764.
# Retrieving Results for Index 531: 82601.
# Retrieving Results for Index 532: 92647.
# Retrieving Results for Index 533: 97477.
# Retrieving Results for Index 534: 91780.
# Retrieving Results for Index 535: 21218.
# Retrieving Results for Index 536: 61115.
# Retrieving Results for Index 537: 62521.
# Retrieving Results for Index 538: 60448.
# Retrieving Results for Index 539: 91384.
# Retrieving Results for Index 540: 92831.
# Retrieving Results for Index 541: 78664.
# Retrieving Results for Index 542: 60639.
# Retrieving Results for Index 543: 98404.
# Retrieving Results for Index 544: 37312.
# Retrieving Results for Index 545: 35950.
# Retrieving Results for Index 546: 91403.
# Retrieving Results for Index 547: 91101.
# Retrieving Results for Index 548: 71801.
# Retrieving Results for Index 549: 44070.
# Retrieving Results for Index 550: 80907.
# Retrieving Results for Index 551: 90059.
# Retrieving Results for Index 552: 28315.
# Retrieving Results for Index 553: 13760.
# Retrieving Results for Index 554: 84084.
# Retrieving Results for Index 555: 25880.
# Retrieving Results for Index 556: 02601.
# Retrieving Results for Index 557: 60505.
# Retrieving Results for Index 558: 15215.
# Retrieving Results for Index 559: 83402.
# Retrieving Results for Index 560: 93117.
# Retrieving Results for Index 561: 12303.
# Retrieving Results for Index 562: 98506.
# Retrieving Results for Index 563: 53575.
# Retrieving Results for Index 564: 94606.
# Retrieving Results for Index 565: 30830.
# Retrieving Results for Index 566: 80906.
# Retrieving Results for Index 567: 83843.
# Retrieving Results for Index 568: 60618.
# Retrieving Results for Index 569: 28215.
# Retrieving Results for Index 570: 97006.
# Retrieving Results for Index 571: 84070.
# Retrieving Results for Index 572: 84094.
# Retrieving Results for Index 573: 90806.
# Retrieving Results for Index 574: 94609.
# Retrieving Results for Index 575: 37774.
# Retrieving Results for Index 576: 21216.
# Retrieving Results for Index 577: 20707.
# Retrieving Results for Index 578: 30341.
# Retrieving Results for Index 579: 06063.
# Retrieving Results for Index 580: 54961.
# Retrieving Results for Index 581: 76117.
# Retrieving Results for Index 582: 37766.
# Retrieving Results for Index 583: 01902.
# Retrieving Results for Index 584: 60534.
# Retrieving Results for Index 585: 56549.
# Retrieving Results for Index 586: 98133.
# Retrieving Results for Index 587: 38111.
# Retrieving Results for Index 588: 98802.
# Retrieving Results for Index 589: 78207.
# Retrieving Results for Index 590: 11203.
# Retrieving Results for Index 591: 32653.
# Retrieving Results for Index 592: 10035.
# Retrieving Results for Index 593: 11229.
# Retrieving Results for Index 594: 11233.
# Retrieving Results for Index 595: 84057.
# Retrieving Results for Index 596: 60615.
# Retrieving Results for Index 597: 11581.
# Retrieving Results for Index 598: 59803.
# Retrieving Results for Index 599: 78521.
# Retrieving Results for Index 600: 97224.
# Retrieving Results for Index 601: 77536.
# Retrieving Results for Index 602: 63114.
# Retrieving Results for Index 603: 96815.
# Retrieving Results for Index 604: 30533.
# Retrieving Results for Index 605: 29527.
# Retrieving Results for Index 606: 32304.
# Retrieving Results for Index 607: 71602.
# Retrieving Results for Index 608: 84041.
# Retrieving Results for Index 609: 97232.
# Retrieving Results for Index 610: 28625.
# Retrieving Results for Index 611: 85014.
# Retrieving Results for Index 612: 98363.
# Retrieving Results for Index 613: 98407.
# Retrieving Results for Index 614: 21230.
# Retrieving Results for Index 615: 85719.
# Retrieving Results for Index 616: 48174.
# Retrieving Results for Index 617: 01833.
# Retrieving Results for Index 618: 80220.
# Retrieving Results for Index 619: 98368.
# Retrieving Results for Index 620: 35243.
# Retrieving Results for Index 621: 07501.
# Retrieving Results for Index 622: 99501.
# Retrieving Results for Index 623: 33135.
# Retrieving Results for Index 624: 94116.
# Retrieving Results for Index 625: 84102.
# Retrieving Results for Index 626: 14607.
# Retrieving Results for Index 627: 60025.
# Retrieving Results for Index 628: 60455.
# Retrieving Results for Index 629: 06330.
# Retrieving Results for Index 630: 73008.
# Retrieving Results for Index 631: 85018.
# Retrieving Results for Index 632: 28306.
# Retrieving Results for Index 633: 83619.
# Retrieving Results for Index 634: 19606.
# Retrieving Results for Index 635: 34135.
# Retrieving Results for Index 636: 80022.
# Retrieving Results for Index 637: 23669.
# Retrieving Results for Index 638: 28216.
# Retrieving Results for Index 639: 06076.
# Retrieving Results for Index 640: 60624.
# Retrieving Results for Index 641: 95201.
# Retrieving Results for Index 642: 01602.
# Retrieving Results for Index 643: 23518.
# Retrieving Results for Index 644: 95125.
# Retrieving Results for Index 645: 81501.
# Retrieving Results for Index 646: 23504.
# Retrieving Results for Index 647: 77575.
# Retrieving Results for Index 648: 89509.
# Retrieving Results for Index 649: 92264.
# Retrieving Results for Index 650: 55320.
# Retrieving Results for Index 651: 91911.
# Retrieving Results for Index 652: 90254.
# Retrieving Results for Index 653: 73942.
# Retrieving Results for Index 654: 01604.
# Retrieving Results for Index 655: 95348.
# Retrieving Results for Index 656: 02143.
# Retrieving Results for Index 657: 92780.
# Retrieving Results for Index 658: 36801.
# Retrieving Results for Index 659: 30312.
# Retrieving Results for Index 660: 32211.
# Retrieving Results for Index 661: 80205.
# Retrieving Results for Index 662: 72736.
# Retrieving Results for Index 663: 98403.
# Retrieving Results for Index 664: 60610.
# Retrieving Results for Index 665: 90720.
# Retrieving Results for Index 666: 97236.
# Retrieving Results for Index 667: 33770.
# Retrieving Results for Index 668: 38024.
# Retrieving Results for Index 669: 11385.
# Retrieving Results for Index 670: 74955.
# Retrieving Results for Index 671: 97220.
# Retrieving Results for Index 672: 16262.
# Retrieving Results for Index 673: 20005.
# Retrieving Results for Index 674: 60655.
# Retrieving Results for Index 675: 87120.
# Retrieving Results for Index 676: 77304.
# Retrieving Results for Index 677: 44113.
# Retrieving Results for Index 678: 95340.
# Retrieving Results for Index 679: 79106.
# Retrieving Results for Index 680: 98402.
# Retrieving Results for Index 681: 78237.
# Retrieving Results for Index 682: 48207.
# Retrieving Results for Index 683: 03908.
# Retrieving Results for Index 684: 90710.
# Retrieving Results for Index 685: 91505.
# Retrieving Results for Index 686: 03303.
# Retrieving Results for Index 687: 53209.
# Retrieving Results for Index 688: 75654.
# Retrieving Results for Index 689: 02150.
# Retrieving Results for Index 690: 20019.
# Retrieving Results for Index 691: 98122.
# Retrieving Results for Index 692: 31305.
# Retrieving Results for Index 693: 30474.
# Retrieving Results for Index 694: 99504.
# Retrieving Results for Index 695: 46516.
# Retrieving Results for Index 696: 06451.
# Retrieving Results for Index 697: 23324.
# Retrieving Results for Index 698: 14620.
# Retrieving Results for Index 699: 81601.
# Retrieving Results for Index 700: 72703.
# Retrieving Results for Index 701: 93703.
# Retrieving Results for Index 702: 19805.
# Retrieving Results for Index 703: 92394.
# Retrieving Results for Index 704: 10474.
# Retrieving Results for Index 705: 60637.
# Retrieving Results for Index 706: 97230.
# Retrieving Results for Index 707: 10952.
# Retrieving Results for Index 708: 71106.
# Retrieving Results for Index 709: 54110.
# Retrieving Results for Index 710: 30680.
# Retrieving Results for Index 711: 07307.
# Retrieving Results for Index 712: 49509.
# Retrieving Results for Index 713: 30117.
# Retrieving Results for Index 714: 97045.
# Retrieving Results for Index 715: 48033.
# Retrieving Results for Index 716: 97080.
# Retrieving Results for Index 717: 92649.
# Retrieving Results for Index 718: 73036.
# Retrieving Results for Index 719: 42431.
# Retrieving Results for Index 720: 19119.
# Retrieving Results for Index 721: 10023.
# Retrieving Results for Index 722: 84015.
# Retrieving Results for Index 723: 11368.
# Retrieving Results for Index 724: 22485.
# Retrieving Results for Index 725: 23513.
# Retrieving Results for Index 726: 98059.
# Retrieving Results for Index 727: 29801.
# Retrieving Results for Index 728: 95926.
# Retrieving Results for Index 729: 55433.
# Retrieving Results for Index 730: 84124.
# Retrieving Results for Index 731: 85704.
# Retrieving Results for Index 732: 80218.
# Retrieving Results for Index 733: 97225.
# Retrieving Results for Index 734: 98284.
# Retrieving Results for Index 735: 78758.
# Retrieving Results for Index 736: 78745.
# Retrieving Results for Index 737: 32504.
# Retrieving Results for Index 738: 94109.
# Retrieving Results for Index 739: 98229.
# Retrieving Results for Index 740: 92840.
# Retrieving Results for Index 741: 41008.
# Retrieving Results for Index 742: 90033.
# Retrieving Results for Index 743: 30060.
# Retrieving Results for Index 744: 98125.
# Retrieving Results for Index 745: 98225.
# Retrieving Results for Index 746: 29102.
# Retrieving Results for Index 747: 11205.
# Retrieving Results for Index 748: 37110.
# Retrieving Results for Index 749: 94041.
# Retrieving Results for Index 750: 80219.
# Retrieving Results for Index 751: 53022.
# Retrieving Results for Index 752: 94608.
# Retrieving Results for Index 753: 92867.
# Retrieving Results for Index 754: 97212.
# Retrieving Results for Index 755: 13204.
# Retrieving Results for Index 756: 90701.
# Retrieving Results for Index 757: 21201.
# Retrieving Results for Index 758: 12205.
# Retrieving Results for Index 759: 33781.
# Retrieving Results for Index 760: 37188.
# Retrieving Results for Index 761: 88220.
# Retrieving Results for Index 762: 91331.
# Retrieving Results for Index 763: 23505.
# Retrieving Results for Index 764: 48473.
# Retrieving Results for Index 765: 50211.
# Retrieving Results for Index 766: 29501.
# Retrieving Results for Index 767: 11691.
# Retrieving Results for Index 768: 15401.
# Retrieving Results for Index 769: 23502.
# Retrieving Results for Index 770: 11226.
# Retrieving Results for Index 771: 63108.
# Retrieving Results for Index 772: 02720.
# Retrieving Results for Index 773: 95032.
# Retrieving Results for Index 774: 14456.
# Retrieving Results for Index 775: 48073.
# Retrieving Results for Index 776: 98102.
# Retrieving Results for Index 777: 29624.
# Retrieving Results for Index 778: 39759.
# Retrieving Results for Index 779: 52801.
# Retrieving Results for Index 780: 73160.
# Retrieving Results for Index 781: 33020.
# Retrieving Results for Index 782: 60623.
# Retrieving Results for Index 783: 79015.
# Retrieving Results for Index 784: 78629.
# Retrieving Results for Index 785: 76013.
# Retrieving Results for Index 786: 19103.
# Retrieving Results for Index 787: 78550.
# Retrieving Results for Index 788: 06120.
# Retrieving Results for Index 789: 99502.
# Retrieving Results for Index 790: 95501.
# Retrieving Results for Index 791: 30525.
# Retrieving Results for Index 792: 28803.
# Retrieving Results for Index 793: 48035.
# Retrieving Results for Index 794: 29406.
# Retrieving Results for Index 795: 94521.
# Retrieving Results for Index 796: 74701.
# Retrieving Results for Index 797: 65672.
# Retrieving Results for Index 798: 78752.
# Retrieving Results for Index 799: 78723.
# Retrieving Results for Index 800: 60651.
# Retrieving Results for Index 801: 35601.
# Retrieving Results for Index 802: 11355.
# Retrieving Results for Index 803: 78217.
# Retrieving Results for Index 804: 32536.
# Retrieving Results for Index 805: 97401.
# Retrieving Results for Index 806: 32901.
# Retrieving Results for Index 807: 37160.
# Retrieving Results for Index 808: 32803.
# Retrieving Results for Index 809: 97702.
# Retrieving Results for Index 810: 02134.
# Retrieving Results for Index 811: 54409.
# Retrieving Results for Index 812: 47150.
# Retrieving Results for Index 813: 94121.
# Retrieving Results for Index 814: 92655.
# Retrieving Results for Index 815: 27707.
# Retrieving Results for Index 816: 32608.
# Retrieving Results for Index 817: 91803.
# Retrieving Results for Index 818: 57032.
# Retrieving Results for Index 819: 97701.
# Retrieving Results for Index 820: 07505.
# Retrieving Results for Index 821: 29670.
# Retrieving Results for Index 822: 70127.
# Retrieving Results for Index 823: 11218.
# Retrieving Results for Index 824: 04083.
# Retrieving Results for Index 825: 90018.
# Retrieving Results for Index 826: 91103.
# Retrieving Results for Index 827: 93402.
# Retrieving Results for Index 828: 32780.
# Retrieving Results for Index 829: 13619.
# Retrieving Results for Index 830: 01105.
# Retrieving Results for Index 831: 97068.
# Retrieving Results for Index 832: 97202.
# Retrieving Results for Index 833: 10029.
# Retrieving Results for Index 834: 20737.
# Retrieving Results for Index 835: 98119.
# Retrieving Results for Index 836: 11231.
# Retrieving Results for Index 837: 83702.
# Retrieving Results for Index 838: 06515.
# Retrieving Results for Index 839: 06052.
# Retrieving Results for Index 840: 97233.
# Retrieving Results for Index 841: 30297.
# Retrieving Results for Index 842: 30534.
# Retrieving Results for Index 843: 11701.
# Retrieving Results for Index 844: 92832.
# Retrieving Results for Index 845: 55331.
# Retrieving Results for Index 846: 79924.
# Retrieving Results for Index 847: 21502.
# Retrieving Results for Index 848: 07086.
# Retrieving Results for Index 849: 27409.
# Retrieving Results for Index 850: 99517.
# Retrieving Results for Index 851: 21217.
# Retrieving Results for Index 852: 06119.
# Retrieving Results for Index 853: 75092.
# Retrieving Results for Index 854: 90201.
# Retrieving Results for Index 855: 33916.
# Retrieving Results for Index 856: 91006.
# Retrieving Results for Index 857: 98372.
# Retrieving Results for Index 858: 02908.
# Retrieving Results for Index 859: 55318.
# Retrieving Results for Index 860: 92117.
# Retrieving Results for Index 861: 17603.
# Retrieving Results for Index 862: 79412.
# Retrieving Results for Index 863: 52060.
# Retrieving Results for Index 864: 97756.
# Retrieving Results for Index 865: 29607.
# Retrieving Results for Index 866: 92115.
# Retrieving Results for Index 867: 11201.
# Retrieving Results for Index 868: 97301.
# Retrieving Results for Index 869: 10472.
# Retrieving Results for Index 870: 35023.
# Retrieving Results for Index 871: 92346.
# Retrieving Results for Index 872: 91106.
# Retrieving Results for Index 873: 89706.
# Retrieving Results for Index 874: 28152.
# Retrieving Results for Index 875: 91342.
# Retrieving Results for Index 876: 82609.
# Retrieving Results for Index 877: 38305.
# Retrieving Results for Index 878: 78602.
# Retrieving Results for Index 879: 93550.
# Retrieving Results for Index 880: 75040.
# Retrieving Results for Index 881: 92843.
# Retrieving Results for Index 882: 70819.
# Retrieving Results for Index 883: 95207.
# Retrieving Results for Index 884: 93610.
# Retrieving Results for Index 885: 31822.
# Retrieving Results for Index 886: 33065.
# Retrieving Results for Index 887: 98032.
# Retrieving Results for Index 888: 95519.
# Retrieving Results for Index 889: 35769.
# Retrieving Results for Index 890: 78130.
# Retrieving Results for Index 891: 35805.
# Retrieving Results for Index 892: 40047.
# Retrieving Results for Index 893: 10701.
# Retrieving Results for Index 894: 34609.
# Retrieving Results for Index 895: 36612.
# Retrieving Results for Index 896: 98531.
# Retrieving Results for Index 897: 50208.
# Retrieving Results for Index 898: 84404.
# Retrieving Results for Index 899: 92833.
# Retrieving Results for Index 900: 43123.
# Retrieving Results for Index 901: 30223.
# Retrieving Results for Index 902: 74012.
# Retrieving Results for Index 903: 45005.
# Retrieving Results for Index 904: 85281.
# Retrieving Results for Index 905: 99508.
# Retrieving Results for Index 906: 13224.
# Retrieving Results for Index 907: 96793.
# Retrieving Results for Index 908: 90715.
# Retrieving Results for Index 909: 98902.
# Retrieving Results for Index 910: 31401.
# Retrieving Results for Index 911: 19082.
# Retrieving Results for Index 912: 60609.
# Retrieving Results for Index 913: 95407.
# Retrieving Results for Index 914: 99354.
# Retrieving Results for Index 915: 73099.
# Retrieving Results for Index 916: 98328.
# Retrieving Results for Index 917: 33767.
# Retrieving Results for Index 918: 95531.
# Retrieving Results for Index 919: 94601.
# Retrieving Results for Index 920: 90503.
# Retrieving Results for Index 921: 91950.
# Retrieving Results for Index 922: 30721.
# Retrieving Results for Index 923: 44240.
# Retrieving Results for Index 924: 78705.
# Retrieving Results for Index 925: 78573.
# Retrieving Results for Index 926: 27407.
# Retrieving Results for Index 927: 98632.
# Retrieving Results for Index 928: 35209.
# Retrieving Results for Index 929: 98105.
# Retrieving Results for Index 930: 97306.
# Retrieving Results for Index 931: 77801.
# Retrieving Results for Index 932: 97146.
# Retrieving Results for Index 933: 94401.
# Retrieving Results for Index 934: 94565.
# Retrieving Results for Index 935: 10466.
# Retrieving Results for Index 936: 98009.
# Retrieving Results for Index 937: 16509.
# Retrieving Results for Index 938: 76201.
# Retrieving Results for Index 939: 56273.
# Retrieving Results for Index 940: 91901.
# Retrieving Results for Index 941: 93304.
# Retrieving Results for Index 942: 29730.
# Retrieving Results for Index 943: 23323.
# Retrieving Results for Index 944: 92553.
# Retrieving Results for Index 945: 28305.
# Retrieving Results for Index 946: 60628.
# Retrieving Results for Index 947: 28217.
# Retrieving Results for Index 948: 74804.
# Retrieving Results for Index 949: 60304.
# Retrieving Results for Index 950: 33714.
# Retrieving Results for Index 951: 19335.
# Retrieving Results for Index 952: 32404.
# Retrieving Results for Index 953: 44106.
# Retrieving Results for Index 954: 60187.
# Retrieving Results for Index 955: 29609.
# Retrieving Results for Index 956: 83301.
# Retrieving Results for Index 957: 60425.
# Retrieving Results for Index 958: 48327.
# Retrieving Results for Index 959: 60617.
# Retrieving Results for Index 960: 46323.
# Retrieving Results for Index 961: 75057.
# Retrieving Results for Index 962: 66202.
# Retrieving Results for Index 963: 32117.
# Retrieving Results for Index 964: 60652.
# Retrieving Results for Index 965: 27534.
# Retrieving Results for Index 966: 29810.
# Retrieving Results for Index 967: 02151.
# Retrieving Results for Index 968: 28348.
# Retrieving Results for Index 969: 79109.
# Retrieving Results for Index 970: 47374.
# Retrieving Results for Index 971: 85302.
# Retrieving Results for Index 972: 10467.
# Retrieving Results for Index 973: 85706.
# Retrieving Results for Index 974: 11373.
# Retrieving Results for Index 975: 80904.
# Retrieving Results for Index 976: 92354.
# Retrieving Results for Index 977: 77539.
# Retrieving Results for Index 978: 16630.
# Retrieving Results for Index 979: 01107.
# Retrieving Results for Index 980: 97478.
# Retrieving Results for Index 981: 01013.
# Retrieving Results for Index 982: 15946.
# Retrieving Results for Index 983: 77532.
# Retrieving Results for Index 984: 29720.
# Retrieving Results for Index 985: 98312.
# Retrieving Results for Index 986: 23454.
# Retrieving Results for Index 987: 31204.
# Retrieving Results for Index 988: 88001.
# Retrieving Results for Index 989: 21207.
# Retrieving Results for Index 990: 98036.
# Retrieving Results for Index 991: 14020.
# Retrieving Results for Index 992: 75204.
# Retrieving Results for Index 993: 91730.
# Retrieving Results for Index 994: 55355.
# Retrieving Results for Index 995: 33771.
# Retrieving Results for Index 996: 10011.
# Retrieving Results for Index 997: 35476.
# Retrieving Results for Index 998: 91754.
# Retrieving Results for Index 999: 97325.
# Retrieving Results for Index 1000: 97132.
# Retrieving Results for Index 1001: 93637.
# Retrieving Results for Index 1002: 84123.
# Retrieving Results for Index 1003: 54449.
# Retrieving Results for Index 1004: 10459.
# Retrieving Results for Index 1005: 95240.
# Retrieving Results for Index 1006: 74023.
# Retrieving Results for Index 1007: 98026.
# Retrieving Results for Index 1008: 06759.
# Retrieving Results for Index 1009: 33990.
# Retrieving Results for Index 1010: 53235.
# Retrieving Results for Index 1011: 98370.
# Retrieving Results for Index 1012: 24592.
# Retrieving Results for Index 1013: 45431.
# Retrieving Results for Index 1014: 11213.
# Retrieving Results for Index 1015: 80918.
# Retrieving Results for Index 1016: 94030.
# Retrieving Results for Index 1017: 90037.
# Retrieving Results for Index 1018: 85901.
# Retrieving Results for Index 1019: 92335.
# Retrieving Results for Index 1020: 06110.
# Retrieving Results for Index 1021: 85021.
# Retrieving Results for Index 1022: 91733.
# Retrieving Results for Index 1023: 29910.
# Retrieving Results for Index 1024: 25404.
# Retrieving Results for Index 1025: 70403.
# Retrieving Results for Index 1026: 75068.
# Retrieving Results for Index 1027: 26505.
# Retrieving Results for Index 1028: 87108.
# Retrieving Results for Index 1029: 78751.
# Retrieving Results for Index 1030: 48532.
# Retrieving Results for Index 1031: 94134.
# Retrieving Results for Index 1032: 91344.
# Retrieving Results for Index 1033: 14203.
# Retrieving Results for Index 1034: 44132.
# Retrieving Results for Index 1035: 98022.
# Retrieving Results for Index 1036: 23430.
# Retrieving Results for Index 1037: 33486.
# Retrieving Results for Index 1038: 23704.
# Retrieving Results for Index 1039: 02149.
# Retrieving Results for Index 1040: 10530.
# Retrieving Results for Index 1041: 90049.
# Retrieving Results for Index 1042: 83440.
# Retrieving Results for Index 1043: 11211.
# Retrieving Results for Index 1044: 34207.
# Retrieving Results for Index 1045: 91042.
# Retrieving Results for Index 1046: 94590.
# Retrieving Results for Index 1047: 44672.
# Retrieving Results for Index 1048: 30120.
# Retrieving Results for Index 1049: 53704.
# Retrieving Results for Index 1050: 43224.
# Retrieving Results for Index 1051: 98056.
# Retrieving Results for Index 1052: 01841.
# Retrieving Results for Index 1053: 07047.
# Retrieving Results for Index 1054: 75061.
# Retrieving Results for Index 1055: 99224.
# Retrieving Results for Index 1056: 80631.
# Retrieving Results for Index 1057: 39305.
# Retrieving Results for Index 1058: 55397.
# Retrieving Results for Index 1059: 23224.
# Retrieving Results for Index 1060: 55803.
# Retrieving Results for Index 1061: 53538.
# Retrieving Results for Index 1062: 60123.
# Retrieving Results for Index 1063: 55364.
# Retrieving Results for Index 1064: 60201.
# Retrieving Results for Index 1065: 88240.
# Retrieving Results for Index 1066: 60403.
# Retrieving Results for Index 1067: 72653.
# Retrieving Results for Index 1068: 75901.
# Retrieving Results for Index 1069: 92503.
# Retrieving Results for Index 1070: 33460.
# Retrieving Results for Index 1071: 95521.
# Retrieving Results for Index 1072: 29644.
# Retrieving Results for Index 1073: 45206.
# Retrieving Results for Index 1074: 03867.
# Retrieving Results for Index 1075: 77494.
# Retrieving Results for Index 1076: 99207.
# Retrieving Results for Index 1077: 10075.
# Retrieving Results for Index 1078: 32789.
# Retrieving Results for Index 1079: 55130.
# Retrieving Results for Index 1080: 93960.
# Retrieving Results for Index 1081: 39564.
# Retrieving Results for Index 1082: 23220.
# Retrieving Results for Index 1083: 22657.
# Retrieving Results for Index 1084: 90402.
# Retrieving Results for Index 1085: 55901.
# Retrieving Results for Index 1086: 84111.
# Retrieving Results for Index 1087: 92705.
# Retrieving Results for Index 1088: 24416.
# Retrieving Results for Index 1089: 20010.
# Retrieving Results for Index 1090: 77071.
# Retrieving Results for Index 1091: 32615.
# Retrieving Results for Index 1092: 01844.
# Retrieving Results for Index 1093: 63130.
# Retrieving Results for Index 1094: 27012.
# Retrieving Results for Index 1095: 92583.
# Retrieving Results for Index 1096: 91340.
# Retrieving Results for Index 1097: 60406.
# Retrieving Results for Index 1098: 85017.
# Retrieving Results for Index 1099: 68066.
# Retrieving Results for Index 1100: 11769.
# Retrieving Results for Index 1101: 75180.
# Retrieving Results for Index 1102: 92075.
# Retrieving Results for Index 1103: 90650.
# Retrieving Results for Index 1104: 13501.
# Retrieving Results for Index 1105: 78657.
# Retrieving Results for Index 1106: 35210.
# Retrieving Results for Index 1107: 70605.
# Retrieving Results for Index 1108: 99202.
# Retrieving Results for Index 1109: 93901.
# Retrieving Results for Index 1110: 77414.
# Retrieving Results for Index 1111: 91423.
# Retrieving Results for Index 1112: 77506.
# Retrieving Results for Index 1113: 53037.
# Retrieving Results for Index 1114: 83686.
# Retrieving Results for Index 1115: 54017.
# Retrieving Results for Index 1116: 29341.
# Retrieving Results for Index 1117: 75751.
# Retrieving Results for Index 1118: 27410.
# Retrieving Results for Index 1119: 15425.
# Retrieving Results for Index 1120: 66216.
# Retrieving Results for Index 1121: 27889.
# Retrieving Results for Index 1122: 31201.
# Retrieving Results for Index 1123: 43551.
# Retrieving Results for Index 1124: 92405.
# Retrieving Results for Index 1125: 92225.
# Retrieving Results for Index 1126: 99518.
# Retrieving Results for Index 1127: 37186.
# Retrieving Results for Index 1128: 70002.
# Retrieving Results for Index 1129: 12047.
# Retrieving Results for Index 1130: 80910.
# Retrieving Results for Index 1131: 06370.
# Retrieving Results for Index 1132: 08021.
# Retrieving Results for Index 1133: 93654.
# Retrieving Results for Index 1134: 92805.
# Retrieving Results for Index 1135: 50701.
# Retrieving Results for Index 1136: 95037.
# Retrieving Results for Index 1137: 79761.
# Retrieving Results for Index 1138: 77504.
# Retrieving Results for Index 1139: 19061.
# Retrieving Results for Index 1140: 14522.
# Retrieving Results for Index 1141: 31029.
# Retrieving Results for Index 1142: 74447.
# Retrieving Results for Index 1143: 77541.
# Retrieving Results for Index 1144: 31008.
# Retrieving Results for Index 1145: 98466.
# Retrieving Results for Index 1146: 15834.
# Retrieving Results for Index 1147: 07081.
# Retrieving Results for Index 1148: 86401.
# Retrieving Results for Index 1149: 93257.
# Retrieving Results for Index 1150: 80206.
# Retrieving Results for Index 1151: 61032.
# Retrieving Results for Index 1152: 94605.
# Retrieving Results for Index 1153: 39339.
# Retrieving Results for Index 1154: 91790.
# Retrieving Results for Index 1155: 78504.
# Retrieving Results for Index 1156: 60453.
# Retrieving Results for Index 1157: 91942.
# Retrieving Results for Index 1158: 98126.
# Retrieving Results for Index 1159: 92882.
# Retrieving Results for Index 1160: 92509.
# Retrieving Results for Index 1161: 92530.
# Retrieving Results for Index 1162: 37830.
# Retrieving Results for Index 1163: 33137.
# Retrieving Results for Index 1164: 98115.
# Retrieving Results for Index 1165: 02780.
# Retrieving Results for Index 1166: 78542.
# Retrieving Results for Index 1167: 75074.
# Retrieving Results for Index 1168: 40299.
# ...
# Retrieving Results for Index 6594: 12545.
# Retrieving Results for Index 6595: 55121.
# Retrieving Results for Index 6596: 52246.
# Retrieving Results for Index 6597: 36869.
# Retrieving Results for Index 6598: 94579.
# Retrieving Results for Index 6599: 60073.
# Retrieving Results for Index 6600: 05753.
# Retrieving Results for Index 6601: 76102.
# Retrieving Results for Index 6602: 22556.
# Retrieving Results for Index 6603: 01103.
# Retrieving Results for Index 6604: 48120.
# Retrieving Results for Index 6605: 92708.
# Retrieving Results for Index 6606: 78634.
# Retrieving Results for Index 6607: 11776.
# Retrieving Results for Index 6608: 19510.
# Retrieving Results for Index 6609: 96789.
# Retrieving Results for Index 6610: 60656.
# Retrieving Results for Index 6611: 13167.
# Retrieving Results for Index 6612: 19343.
# Retrieving Results for Index 6613: 29492.
# Retrieving Results for Index 6614: 19015.
# Retrieving Results for Index 6615: 11514.
# Retrieving Results for Index 6616: 32746.
# Retrieving Results for Index 6617: 75126.
# Retrieving Results for Index 6618: 32750.
# Retrieving Results for Index 6619: 78747.
# Retrieving Results for Index 6620: 22312.
# Retrieving Results for Index 6621: 85054.
# Retrieving Results for Index 6622: 15101.
# Retrieving Results for Index 6623: 80031.
# Retrieving Results for Index 6624: 44144.
# Retrieving Results for Index 6625: 21901.
# Retrieving Results for Index 6626: 55432.
# Retrieving Results for Index 6627: 22181.
# Retrieving Results for Index 6628: 20724.
# Retrieving Results for Index 6629: 33418.
# Retrieving Results for Index 6630: 19709.
# Retrieving Results for Index 6631: 40508.
# Retrieving Results for Index 6632: 85375.
# Retrieving Results for Index 6633: 32836.
# Retrieving Results for Index 6634: 33896.
# Retrieving Results for Index 6635: 60134.
# Retrieving Results for Index 6636: 70360.
# Retrieving Results for Index 6637: 34683.
# Retrieving Results for Index 6638: 32128.
# Retrieving Results for Index 6639: 19096.
# Retrieving Results for Index 6640: 21409.
# Retrieving Results for Index 6641: 34211.
# Retrieving Results for Index 6642: 32317.
# Retrieving Results for Index 6643: 89002.
# Retrieving Results for Index 6644: 60654.
# Retrieving Results for Index 6645: 10927.
# Retrieving Results for Index 6646: 06109.
# Retrieving Results for Index 6647: 66221.
# Retrieving Results for Index 6648: 95133.
# Retrieving Results for Index 6649: 60181.
# Retrieving Results for Index 6650: 70119.
# Retrieving Results for Index 6651: 33548.
# Retrieving Results for Index 6652: 90746.
# Retrieving Results for Index 6653: 89139.
# Retrieving Results for Index 6654: 20876.
# Retrieving Results for Index 6655: 30017.
# Retrieving Results for Index 6656: 08805.
# Retrieving Results for Index 6657: 94598.
# Retrieving Results for Index 6658: 34238.
# Retrieving Results for Index 6659: 37179.
# Retrieving Results for Index 6660: 33322.
# Retrieving Results for Index 6661: 02532.
# Retrieving Results for Index 6662: 60012.
# Retrieving Results for Index 6663: 91208.
# Retrieving Results for Index 6664: 38002.
# Retrieving Results for Index 6665: 10473.
# Retrieving Results for Index 6666: 84095.
# Retrieving Results for Index 6667: 89131.
# Retrieving Results for Index 6668: 85658.
# Retrieving Results for Index 6669: 10523.
# Retrieving Results for Index 6670: 77389.
# Retrieving Results for Index 6671: 91024.
# Retrieving Results for Index 6672: 32712.
# Retrieving Results for Index 6673: 10017.
# Retrieving Results for Index 6674: 77354.
# Retrieving Results for Index 6675: 94551.
# Retrieving Results for Index 6676: 19120.
# Retrieving Results for Index 6677: 75078.
# Retrieving Results for Index 6678: 29455.
# Retrieving Results for Index 6679: 48168.
# Retrieving Results for Index 6680: 78255.
# Retrieving Results for Index 6681: 60516.
# Retrieving Results for Index 6682: 34202.
# Retrieving Results for Index 6683: 37174.
# Retrieving Results for Index 6684: 20018.
# Retrieving Results for Index 6685: 78257.
# Retrieving Results for Index 6686: 48381.
# Retrieving Results for Index 6687: 77003.
# Retrieving Results for Index 6688: 11365.
# Retrieving Results for Index 6689: 64154.
# Retrieving Results for Index 6690: 33762.
# Retrieving Results for Index 6691: 19086.
# Retrieving Results for Index 6692: 78235.
# Retrieving Results for Index 6693: 95208.
# Retrieving Results for Index 6694: 34685.
# Retrieving Results for Index 6695: 20120.
# Retrieving Results for Index 6696: 76182.
# Retrieving Results for Index 6697: 92590.
# Retrieving Results for Index 6698: 98271.
# Retrieving Results for Index 6699: 49321.
# Retrieving Results for Index 6700: 08857.
# Retrieving Results for Index 6701: 33705.
# Retrieving Results for Index 6702: 20874.
# Retrieving Results for Index 6703: 77005.
# Retrieving Results for Index 6704: 30305.
# Retrieving Results for Index 6705: 23510.
# Retrieving Results for Index 6706: 11210.
# Retrieving Results for Index 6707: 32250.
# Retrieving Results for Index 6708: 92604.
# Retrieving Results for Index 6709: 80923.
# Retrieving Results for Index 6710: 01923.
# Retrieving Results for Index 6711: 78738.
# Retrieving Results for Index 6712: 89149.
# Retrieving Results for Index 6713: 48105.
# Retrieving Results for Index 6714: 22079.
# Retrieving Results for Index 6715: 33027.
# Retrieving Results for Index 6716: 76087.
# Retrieving Results for Index 6717: 06042.
# Retrieving Results for Index 6718: 94022.
# Retrieving Results for Index 6719: 23113.
# Retrieving Results for Index 6720: 11725.
# Retrieving Results for Index 6721: 28079.
# Retrieving Results for Index 6722: 11940.
# Retrieving Results for Index 6723: 34990.
# Retrieving Results for Index 6724: 92808.
# Retrieving Results for Index 6725: 21015.
# Retrieving Results for Index 6726: 92620.
# Retrieving Results for Index 6727: 11501.
# Retrieving Results for Index 6728: 21113.
# Retrieving Results for Index 6729: 33483.
# Retrieving Results for Index 6730: 33131.
# Retrieving Results for Index 6731: 28277.
# Retrieving Results for Index 6732: 92629.
# Retrieving Results for Index 6733: 78215.
# Retrieving Results for Index 6734: 78260.
# Retrieving Results for Index 6735: 80111.
# Retrieving Results for Index 6736: 80124.
# Retrieving Results for Index 6737: 15142.
# Retrieving Results for Index 6738: 80016.
# Retrieving Results for Index 6739: 80235.
# Retrieving Results for Index 6740: 19440.
# Retrieving Results for Index 6741: 40059.
# Retrieving Results for Index 6742: 01749.
# Retrieving Results for Index 6743: 20171.
# Retrieving Results for Index 6744: 32824.
# Retrieving Results for Index 6745: 60070.
# Retrieving Results for Index 6746: 02879.
# Retrieving Results for Index 6747: 33304.
# Retrieving Results for Index 6748: 05482.
# Retrieving Results for Index 6749: 75244.
# Retrieving Results for Index 6750: 84128.
# Retrieving Results for Index 6751: 15120.
# Retrieving Results for Index 6752: 18109.
# Retrieving Results for Index 6753: 02116.
# Retrieving Results for Index 6754: 49301.
# Retrieving Results for Index 6755: 77094.
# Retrieving Results for Index 6756: 84081.
# Retrieving Results for Index 6757: 20712.
# Retrieving Results for Index 6758: 33905.
# Retrieving Results for Index 6759: 80023.
# Retrieving Results for Index 6760: 07751.
# Retrieving Results for Index 6761: 23112.
# Retrieving Results for Index 6762: 22315.
# Retrieving Results for Index 6763: 92532.
# Retrieving Results for Index 6764: 30115.
# Retrieving Results for Index 6765: 63005.
# Retrieving Results for Index 6766: 32832.
# Retrieving Results for Index 6767: 08052.
# Retrieving Results for Index 6768: 89135.
# Retrieving Results for Index 6769: 23435.
# Retrieving Results for Index 6770: 80528.
# Retrieving Results for Index 6771: 48116.
# Retrieving Results for Index 6772: 49685.
# Retrieving Results for Index 6773: 48176.
# Retrieving Results for Index 6774: 06033.
# Retrieving Results for Index 6775: 02828.
# Retrieving Results for Index 6776: 33004.
# Retrieving Results for Index 6777: 48314.
# Retrieving Results for Index 6778: 80015.
# Retrieving Results for Index 6779: 28031.
# Retrieving Results for Index 6780: 33812.
# Retrieving Results for Index 6781: 21122.
# Retrieving Results for Index 6782: 21042.
# Retrieving Results for Index 6783: 94588.
# Retrieving Results for Index 6784: 92688.
# Retrieving Results for Index 6785: 10026.
# Retrieving Results for Index 6786: 80126.
# Retrieving Results for Index 6787: 89084.
# Retrieving Results for Index 6788: 11749.
# Retrieving Results for Index 6789: 08801.
# Retrieving Results for Index 6790: 92614.
# Retrieving Results for Index 6791: 93730.
# Retrieving Results for Index 6792: 87113.
# Retrieving Results for Index 6793: 19341.
# Retrieving Results for Index 6794: 11801.
# Retrieving Results for Index 6795: 20774.
# Retrieving Results for Index 6796: 94089.
# Retrieving Results for Index 6797: 32097.
# Retrieving Results for Index 6798: 33966.
# Retrieving Results for Index 6799: 60458.
# Retrieving Results for Index 6800: 92007.
# Retrieving Results for Index 6801: 30066.
# Retrieving Results for Index 6802: 02351.
# Retrieving Results for Index 6803: 07869.
# Retrieving Results for Index 6804: 92606.
# Retrieving Results for Index 6805: 33062.
# Retrieving Results for Index 6806: 80239.
# Retrieving Results for Index 6807: 32204.
# Retrieving Results for Index 6808: 33331.
# Retrieving Results for Index 6809: 92679.
# Retrieving Results for Index 6810: 90703.
# Retrieving Results for Index 6811: 33172.
# Retrieving Results for Index 6812: 11758.
# Retrieving Results for Index 6813: 20175.
# Retrieving Results for Index 6814: 89511.
# Retrieving Results for Index 6815: 10019.
# Retrieving Results for Index 6816: 78732.
# Retrieving Results for Index 6817: 80108.
# Retrieving Results for Index 6818: 33174.
# Retrieving Results for Index 6819: 91752.
# Retrieving Results for Index 6820: 36064.
# Retrieving Results for Index 6821: 15238.
# Retrieving Results for Index 6822: 94568.
# Retrieving Results for Index 6823: 22044.
# Retrieving Results for Index 6824: 33635.
# Retrieving Results for Index 6825: 92691.
# Retrieving Results for Index 6826: 07601.
# Retrieving Results for Index 6827: 76227.
# Retrieving Results for Index 6828: 19462.
# Retrieving Results for Index 6829: 94303.
# Retrieving Results for Index 6830: 68133.
# Retrieving Results for Index 6831: 60093.
# Retrieving Results for Index 6832: 70112.
# Retrieving Results for Index 6833: 32829.
# Retrieving Results for Index 6834: 20895.
# Retrieving Results for Index 6835: 19342.
# Retrieving Results for Index 6836: 60475.
# Retrieving Results for Index 6837: 60543.
# Retrieving Results for Index 6838: 33040.
# Retrieving Results for Index 6839: 20148.
# Retrieving Results for Index 6840: 43202.
# Retrieving Results for Index 6841: 94547.
# Retrieving Results for Index 6842: 02019.
# Retrieving Results for Index 6843: 06002.
# Retrieving Results for Index 6844: 10547.
# Retrieving Results for Index 6845: 27856.
# Retrieving Results for Index 6846: 33414.
# Retrieving Results for Index 6847: 12144.
# Retrieving Results for Index 6848: 34786.
# Retrieving Results for Index 6849: 33067.
# Retrieving Results for Index 6850: 94530.
# Retrieving Results for Index 6851: 34639.
# Retrieving Results for Index 6852: 19803.
# Retrieving Results for Index 6853: 20003.
# Retrieving Results for Index 6854: 34113.
# Retrieving Results for Index 6855: 19154.
# Retrieving Results for Index 6856: 98199.
# Retrieving Results for Index 6857: 22015.
# Retrieving Results for Index 6858: 15203.
# Retrieving Results for Index 6859: 22303.
# Retrieving Results for Index 6860: 60051.
# Retrieving Results for Index 6861: 91506.
# Retrieving Results for Index 6862: 75225.
# Retrieving Results for Index 6863: 60118.
# Retrieving Results for Index 6864: 33967.
# Retrieving Results for Index 6865: 15317.
# Retrieving Results for Index 6866: 60564.
# Retrieving Results for Index 6867: 15090.
# Retrieving Results for Index 6868: 33919.
# Retrieving Results for Index 6869: 06067.
# Retrieving Results for Index 6870: 33028.
# Retrieving Results for Index 6871: 66211.
# Retrieving Results for Index 6872: 60008.
# Retrieving Results for Index 6873: 94124.
# Retrieving Results for Index 6874: 11106.
# Retrieving Results for Index 6875: 85255.
# Retrieving Results for Index 6876: 10280.
# Retrieving Results for Index 6877: 22042.
# Retrieving Results for Index 6878: 77406.
# Retrieving Results for Index 6879: 07029.
# Retrieving Results for Index 6880: 60502.
# Retrieving Results for Index 6881: 60169.
# Retrieving Results for Index 6882: 33823.
# Retrieving Results for Index 6883: 33196.
# Retrieving Results for Index 6884: 33872.
# Retrieving Results for Index 6885: 34744.
# Retrieving Results for Index 6886: 19518.
# Retrieving Results for Index 6887: 98040.
# Retrieving Results for Index 6888: 85742.
# Retrieving Results for Index 6889: 20716.
# Retrieving Results for Index 6890: 92124.
# Retrieving Results for Index 6891: 75028.
# Retrieving Results for Index 6892: 92130.
# Retrieving Results for Index 6893: 01605.
# Retrieving Results for Index 6894: 95757.
# Retrieving Results for Index 6895: 33435.
# Retrieving Results for Index 6896: 95742.
# Retrieving Results for Index 6897: 19129.
# Retrieving Results for Index 6898: 94582.
# Retrieving Results for Index 6899: 80924.
# Retrieving Results for Index 6900: 92707.
# Retrieving Results for Index 6901: 07470.
# Retrieving Results for Index 6902: 33445.
# Retrieving Results for Index 6903: 08096.
# Retrieving Results for Index 6904: 44124.
# Retrieving Results for Index 6905: 20817.
# Retrieving Results for Index 6906: 01864.
# Retrieving Results for Index 6907: 33018.
# Retrieving Results for Index 6908: 34212.
# Retrieving Results for Index 6909: 34119.
# Retrieving Results for Index 6910: 22302.
# Retrieving Results for Index 6911: 10038.
# Retrieving Results for Index 6912: 91739.
# Retrieving Results for Index 6913: 92612.
# Retrieving Results for Index 6914: 95817.
# Retrieving Results for Index 6915: 22305.
# Retrieving Results for Index 6916: 92782.
# Retrieving Results for Index 6917: 01803.
# Retrieving Results for Index 6918: 07652.
# Retrieving Results for Index 6919: 33626.
# Retrieving Results for Index 6920: 08723.
# Retrieving Results for Index 6921: 02026.
# Retrieving Results for Index 6922: 21212.
# Retrieving Results for Index 6923: 20816.
# Retrieving Results for Index 6924: 80129.
# Retrieving Results for Index 6925: 94404.
# Retrieving Results for Index 6926: 95864.
# Retrieving Results for Index 6927: 08536.
# Retrieving Results for Index 6928: 60062.
# Retrieving Results for Index 6929: 33323.
# Retrieving Results for Index 6930: 07304.
# Retrieving Results for Index 6931: 06905.
# Retrieving Results for Index 6932: 22310.
# Retrieving Results for Index 6933: 07095.
# Retrieving Results for Index 6934: 11797.
# Retrieving Results for Index 6935: 12524.
# Retrieving Results for Index 6936: 03038.
# Retrieving Results for Index 6937: 99203.
# Retrieving Results for Index 6938: 11722.
# Retrieving Results for Index 6939: 08107.
# Retrieving Results for Index 6940: 60301.
# Retrieving Results for Index 6941: 10605.
# Retrieving Results for Index 6942: 33134.
# Retrieving Results for Index 6943: 33487.
# Retrieving Results for Index 6944: 33180.
# Retrieving Results for Index 6945: 20855.
# Retrieving Results for Index 6946: 08852.
# Retrieving Results for Index 6947: 46256.
# Retrieving Results for Index 6948: 46319.
# Retrieving Results for Index 6949: 91381.
# Retrieving Results for Index 6950: 20815.
# Retrieving Results for Index 6951: 33558.
# Retrieving Results for Index 6952: 91302.
# Retrieving Results for Index 6953: 11427.
# Retrieving Results for Index 6954: 10306.
# Retrieving Results for Index 6955: 96797.
# Retrieving Results for Index 6956: 11109.
# Retrieving Results for Index 6957: 60090.
# Retrieving Results for Index 6958: 33181.
# Retrieving Results for Index 6959: 20166.
# Retrieving Results for Index 6960: 85284.
# Retrieving Results for Index 6961: 12590.
# Retrieving Results for Index 6962: 07058.
# Retrieving Results for Index 6963: 94132.
# Retrieving Results for Index 6964: 94304.
# Retrieving Results for Index 6965: 92602.
# Retrieving Results for Index 6966: 10005.
# Retrieving Results for Index 6967: 10036.
# Retrieving Results for Index 6968: 02451.
# Retrieving Results for Index 6969: 11713.
# Retrieving Results for Index 6970: 92108.
# Retrieving Results for Index 6971: 89441.
# Retrieving Results for Index 6972: 07083.
# Retrieving Results for Index 6973: 10044.

# %%
# # Save results from API requests
# with open('zipcode_locations.json', 'w') as file_out:
#     json.dump(results_list, file_out)

# %%
# Load results from API requests
with open('temp/zipcode_locations.json', 'r') as file_in:
    zipcode_locations = json.load(file_in)

# %%
# Example API results
zipcode_locations[0]
# Out:
# [{'address_components': [{'long_name': '92626',
#     'short_name': '92626',
#     'types': ['postal_code']},
#    {'long_name': 'Costa Mesa',
#     'short_name': 'Costa Mesa',
#     'types': ['locality', 'political']},
#    {'long_name': 'Orange County',
#     'short_name': 'Orange County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'California',
#     'short_name': 'CA',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Costa Mesa, CA 92626, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 33.701975, 'lng': -117.8642701},
#     'southwest': {'lat': 33.65618, 'lng': -117.946433}},
#    'location': {'lat': 33.6834142, 'lng': -117.9073244},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 33.701975, 'lng': -117.8642701},
#     'southwest': {'lat': 33.65618, 'lng': -117.946433}}},
#   'place_id': 'ChIJj4r82UHf3IARLQc40-4zqpY',
#   'types': ['postal_code']}]

# %% [markdown]
# According to the Google API documentation, `locality` is the address type that corresponds to city, and `administrative_area_level_1` is the address type that corresponds to state. However, sometimes `locality` does not exist in API results. Ideally, I would look up their exact city names. For the sake of time in this project, I'm going to use the second element in the `address_components` list as a proxy for the city.

# %%
# Define a function to retrieve city and state information from API results of a particular zip code
def retrieve_city_state(index, results, zipcode_unique=zipcode_unique):
    '''
    Retrieve city and state information from API results
    INPUTS:
        index (int) - index of the particular zip code in `zipcode_unique`
        results (list) - list of API results of the particular zip code
        zipcode_unique (list) - list of unique zip code in the raw data
    OUTPUTS:
        city (str or NaN) - name of the corresponding city
        state (str or NaN) - name of the corresponding state
    '''
    city = np.nan
    state = np.nan
    if (results):
        address = results[0].get("address_components", "")
            
        for component in address:
            if 'locality' in component['types']:
                city = component.get("short_name", "") # protect from keyError
            elif 'administrative_area_level_1' in component['types']:
                state = component.get("short_name", "")
        
        # If locality does not exist in the API results
        if city is np.nan:
            city = address[1].get("short_name", "")
    else:
        print(f"No results for Index {index}: {zipcode_unique[index]}")
        
    return city, state

# %%
# Retrieve city and state information from API results
city_list = []
state_list = []

for index, results in enumerate(zipcode_locations):

    city, state = retrieve_city_state(index, results, zipcode_unique=zipcode_unique)
    city_list.append(city)
    state_list.append(state)
# Out:
# No results for Index 4623: 85220
# No results for Index 5886: 85219
# No results for Index 6020: 85223
# No results for Index 6268: 85242

# %% [markdown]
# It appears that zip code 85220, 85219, 85223, and 85242 do not have valid city and state information. A closer look up on [USPS website](https://about.usps.com/postal-bulletin/2009/pb22259/html/info_001.htm) shows that these are the old codes and should be updated to the new ones: 85120, 85119, 85123, and 85142.

# %%
# Update zip codes and retrieve city and state info again
indices = [4623, 5886, 6020, 6268]
old_zipcode = [85220, 85219, 85223, 85242]
new_zipcode = [85120, 85119, 85123, 85142]

for i, index in enumerate(indices):
    
    # API request using the updated zip codes
    target_zipcode = new_zipcode[i]
    params['components'] = f"country:US|postal_code:{target_zipcode}"
    print(f"Retrieving Results for Index {index}: {target_zipcode}.")
    response = requests.get(base_url, params=params).json()
    results = response.get('results')
    
    # Retrieve city and state information
    city, state = retrieve_city_state(index, results, zipcode_unique=zipcode_unique)
    city_list[index] = city
    state_list[index] = state
# Out:
# Retrieving Results for Index 4623: 85120.
# Retrieving Results for Index 5886: 85119.
# Retrieving Results for Index 6020: 85123.
# Retrieving Results for Index 6268: 85142.

# %%
# Combine zipcode, city, and state info into dictionary for easy query
zipcode_dict = {}
for index, zipcode in enumerate(zipcode_unique):
    zipcode_dict[zipcode] = {'city': city_list[index], 'state': state_list[index]}

# %%
# Fill in city and state info based on zip code
df['City'] = df['Zip'].apply(lambda x: zipcode_dict[x]['city'])
df['State'] = df['Zip'].apply(lambda x: zipcode_dict[x]['state'])
df.head()
# Out:
#    Deal ID  Lender ID    Zip            City State Multifamily Subtype Built  \
# 0  14454.0       19.0  92626      Costa Mesa    CA              Garden  1990
# 1  20421.0       19.0  91406     Los Angeles    CA              Garden  1962
# 2  24298.0       50.0  70122     New Orleans    LA              Garden  2009
# 3   2853.0       19.0  90046  West Hollywood    CA              Garden  1957
# 4   3023.0       51.0  11215        Brooklyn    NY              Garden  2002
#
#     Units Original Loan  Note Rate  Loan Term (Original) Appraised Value  \
# 0    24.0      1,720,000      5.8%                 180.0       3,500,000
# 1    15.0        500,000      5.3%                 180.0       1,525,000
# 2   164.0        250,000      6.9%                 120.0       4,187,586
# 3    11.0        805,000      5.2%                 180.0       2,450,000
# 4    13.0      1,600,000      6.5%                 120.0       3,112,000
#
#   Maturity Date      UPB Amort DSvc  Orig Amort  IO Period
# 0        2/1/19   28,379     14,292       180.0        0.0
# 1       12/1/19   46,916      4,022       180.0        0.0
# 2        1/1/21   67,161      2,892       120.0        0.0
# 3        8/1/20  123,314      6,450       180.0        0.0
# 4        7/1/19  124,669     18,200       120.0        0.0

# %%
# Sanity check
print(f"The dataset has {df['State'].nunique()} unique states.")
# Out:
# The dataset has 51 unique states.

# %% [markdown]
# ### 1.3. Sanity check of the table

# %%
# Column name
df.columns
# Out:
# Index(['Deal ID', 'Lender ID', 'Zip', 'City', 'State', 'Multifamily Subtype',
#        'Built', ' Units', 'Original Loan ', 'Note Rate',
#        'Loan Term (Original)', 'Appraised Value', 'Maturity Date', 'UPB',
#        'Amort DSvc', 'Orig Amort', 'IO Period'],
#       dtype='object')

# %%
# Clean up column name
df.columns = [col.strip() for col in df.columns]
df.columns
# Out:
# Index(['Deal ID', 'Lender ID', 'Zip', 'City', 'State', 'Multifamily Subtype',
#        'Built', 'Units', 'Original Loan', 'Note Rate', 'Loan Term (Original)',
#        'Appraised Value', 'Maturity Date', 'UPB', 'Amort DSvc', 'Orig Amort',
#        'IO Period'],
#       dtype='object')

# %%
# Check the number of missing values in Lender ID
id_col = 'Lender ID'
missing_id = df.loc[(df[id_col].isnull()) | (df[id_col] == ""), id_col]
print(f"Number of missing values in Lender ID column: {missing_id.count()}")
# Out:
# Number of missing values in Lender ID column: 0
# /anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
# Check the number of missing values in other features
print("Number of missing values in each column:")
df.isnull().sum()
# Out:
# Number of missing values in each column:
# Deal ID                 0
# Lender ID               0
# Zip                     0
# City                    0
# State                   0
# Multifamily Subtype     0
# Built                   0
# Units                   0
# Original Loan           0
# Note Rate               0
# Loan Term (Original)    0
# Appraised Value         0
# Maturity Date           0
# UPB                     0
# Amort DSvc              0
# Orig Amort              0
# IO Period               0
# dtype: int64

# %%
# Drop duplicated rows
df = df.drop_duplicates()
print(f"Number of duplicated rows left: {df.duplicated().sum()}")
# Out:
# Number of duplicated rows left: 0

# %% [markdown]
# At this point, no missing value or duplicated row.

# %% [markdown]
# ### 1.4. Save checkpoint

# %%
# Save dataframe into sqlite
engine = create_engine('sqlite:///../data/lender_data1.db')
df.to_sql('Lender', engine, index=False, if_exists='replace')
# engine.dispose()

# Save as a checkpoint
df.to_csv("temp/lender_checkpoint_1.csv", index=False)
